# %%
import pandas as pd
import sqlite3
import dask.dataframe as dd

# %%
df = pd.read_csv('D:\\Downloads\\ebd_US_relAug-2022\\ebd_US_relAug-2022.txt\\ebd_US_relAug-2022.txt',sep='\t', chunksize=1000)

# %%
count=0
for x in df:
    count = count + 1 
    if count % 1000 == 0:
        print(count)
    else:
        pass
print(count)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
df = dd.read_table('D:\\Downloads\\ebd_US_relAug-2022\\ebd_US_relAug-2022.txt\\ebd_US_relAug-2022.txt',dtype={'AGE/SEX': 'object',
       'ATLAS BLOCK': 'object',
       'BCR CODE': 'float64',
       'EXOTIC CODE': 'object',
       'GROUP IDENTIFIER': 'object',
       'USFWS CODE': 'object',
        'REASON': 'object'})

# %%
df
# Out:
# Dask DataFrame Structure:
#                  GLOBAL UNIQUE IDENTIFIER LAST EDITED DATE TAXONOMIC ORDER CATEGORY TAXON CONCEPT ID COMMON NAME SCIENTIFIC NAME SUBSPECIES COMMON NAME SUBSPECIES SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE BREEDING CATEGORY BEHAVIOR CODE AGE/SEX COUNTRY COUNTRY CODE   STATE STATE CODE  COUNTY COUNTY CODE IBA CODE BCR CODE USFWS CODE ATLAS BLOCK LOCALITY LOCALITY ID LOCALITY TYPE LATITUDE LONGITUDE OBSERVATION DATE TIME OBSERVATIONS STARTED OBSERVER ID SAMPLING EVENT IDENTIFIER PROTOCOL TYPE PROTOCOL CODE PROJECT CODE DURATION MINUTES EFFORT DISTANCE KM EFFORT AREA HA NUMBER OBSERVERS ALL SPECIES REPORTED GROUP IDENTIFIER HAS MEDIA APPROVED REVIEWED  REASON TRIP COMMENTS SPECIES COMMENTS
# npartitions=4686
# ...

# %%
df.head()
# Out:
#                          GLOBAL UNIQUE IDENTIFIER            LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS265484922  2021-03-30 00:20:41.916545
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS509189087  2021-03-25 20:48:39.476105
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS509189088  2021-03-25 20:48:39.476105
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS571166222  2021-03-26 09:17:43.931549
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS583785975  2021-04-01 17:52:32.050575
#
#    TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID            COMMON NAME  \
# 0            11374     issf  avibase-6B7F47D8       Northern Flicker
# 1              303  species  avibase-B59E1863           Canada Goose
# 2              663  species  avibase-68EA281A       Common Goldeneye
# 3            33040  species  avibase-BC5A9498  Yellow-rumped Warbler
# 4             5359  species  avibase-4FB248BA          American Coot
#
#       SCIENTIFIC NAME             SUBSPECIES COMMON NAME  \
# ...

# %%
condor = df[df['COMMON NAME']=='California Condor']

# %%
condor.head()
# Out:
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\core.py:7117: UserWarning: Insufficient elements for `head`. 5 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   f"Insufficient elements for `head`. {n} elements requested, only {len(r)} "
#                                GLOBAL UNIQUE IDENTIFIER  \
# 5508    URN:CornellLabOfOrnithology:EBIRD:OBS1313836846
# 61721    URN:CornellLabOfOrnithology:EBIRD:OBS290744400
# 109625   URN:CornellLabOfOrnithology:EBIRD:OBS200602195
# 110766   URN:CornellLabOfOrnithology:EBIRD:OBS630489838
#
#                   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  \
# 5508    2022-01-08 15:21:44.063086             7409  species
# 61721          2015-01-18 19:05:31             7409  species
# 109625         2015-07-16 13:57:00             7409  species
# 110766         2018-06-12 17:01:41             7409  species
#
#         TAXON CONCEPT ID        COMMON NAME          SCIENTIFIC NAME  \
# ...

# %%
condor.to_csv('condor.csv')
# Out:
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (7,8,11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (7,8,10,11,12,13,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (48) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (46) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# ...

# %%
twentytwenty = df[df['LAST EDITED DATE']>'1/1/2020']

# %%
twentytwenty.head()
# Out:
#                          GLOBAL UNIQUE IDENTIFIER            LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS265484922  2021-03-30 00:20:41.916545
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS509189087  2021-03-25 20:48:39.476105
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS509189088  2021-03-25 20:48:39.476105
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS571166222  2021-03-26 09:17:43.931549
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS583785975  2021-04-01 17:52:32.050575
#
#    TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID            COMMON NAME  \
# 0            11374     issf  avibase-6B7F47D8       Northern Flicker
# 1              303  species  avibase-B59E1863           Canada Goose
# 2              663  species  avibase-68EA281A       Common Goldeneye
# 3            33040  species  avibase-BC5A9498  Yellow-rumped Warbler
# 4             5359  species  avibase-4FB248BA          American Coot
#
#       SCIENTIFIC NAME             SUBSPECIES COMMON NAME  \
# ...

# %%
twentytwenty.to_csv('2020.csv')
# Out:
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (7,8,11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (7,8,10,11,12,13,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# C:\Users\mpden\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py:137: DtypeWarning: Columns (48) have mixed types.Specify dtype option on import or set low_memory=False.
#   path_info,
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-971588c58ee0> in <module>
# ...
